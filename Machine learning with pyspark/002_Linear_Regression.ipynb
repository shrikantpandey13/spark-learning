# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://www-us.apache.org/dist/spark/spark-3.0.0-preview2/spark-3.0.0-preview2-bin-hadoop3.2.tgz
# !tar -xvf spark-3.0.0-preview2-bin-hadoop3.2.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-preview2-bin-hadoop3.2"
# Out:
# spark-3.0.0-preview2-bin-hadoop3.2/
# spark-3.0.0-preview2-bin-hadoop3.2/data/
# spark-3.0.0-preview2-bin-hadoop3.2/data/streaming/
# spark-3.0.0-preview2-bin-hadoop3.2/data/streaming/AFINN-111.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/sample_binary_classification_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/sample_kmeans_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/sample_multiclass_classification_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/sample_lda_libsvm_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/iris_libsvm.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/pagerank_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/sample_linear_regression_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/pic_data.txt
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/als/
# spark-3.0.0-preview2-bin-hadoop3.2/data/mllib/als/test.data
# ...

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-437c5079-c6b4-4685-be89-06f9c6f30652" name="files[]" multiple disabled />
#      <output id="result-437c5079-c6b4-4685-be89-06f9c6f30652">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Linear_regression_dataset.csv to Linear_regression_dataset.csv

# %%
#create sparksession object
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('lin_reg').getOrCreate()

# %%
#import Linear Regression from spark's MLlib
from pyspark.ml.regression import LinearRegression

# %%
#Load the dataset
df=spark.read.csv('Linear_regression_dataset.csv',inferSchema=True,header=True)

# %%
df.show()
# Out:
# +-----+-----+-----+-----+-----+------+
# |var_1|var_2|var_3|var_4|var_5|output|
# +-----+-----+-----+-----+-----+------+
# |  734|  688|   81|0.328|0.259| 0.418|
# |  700|  600|   94| 0.32|0.247| 0.389|
# |  712|  705|   93|0.311|0.247| 0.417|
# |  734|  806|   69|0.315| 0.26| 0.415|
# |  613|  759|   61|0.302| 0.24| 0.378|
# |  748|  676|   85|0.318|0.255| 0.422|
# |  669|  588|   97|0.315|0.251| 0.411|
# |  667|  845|   68|0.324|0.251| 0.381|
# |  758|  890|   64| 0.33|0.274| 0.436|
# |  726|  670|   88|0.335|0.268| 0.422|
# |  583|  794|   55|0.302|0.236| 0.371|
# |  676|  746|   72|0.317|0.265|   0.4|
# |  767|  699|   89|0.332|0.274| 0.433|
# |  637|  597|   86|0.317|0.252| 0.374|
# |  609|  724|   69|0.308|0.244| 0.382|
# |  776|  733|   83|0.325|0.259| 0.437|
# |  701|  832|   66|0.325| 0.26|  0.39|
# |  650|  709|   74|0.316|0.249| 0.386|
# |  804|  668|   95|0.337|0.265| 0.453|
# |  713|  614|   94| 0.31|0.238| 0.404|
# +-----+-----+-----+-----+-----+------+
# ...

# %%
# shape of dataframe
print((df.count(), len(df.columns)))
# Out:
# (1232, 6)

# %%
#types of columns
df.printSchema()
# Out:
# root
#  |-- var_1: integer (nullable = true)
#  |-- var_2: integer (nullable = true)
#  |-- var_3: integer (nullable = true)
#  |-- var_4: double (nullable = true)
#  |-- var_5: double (nullable = true)
#  |-- output: double (nullable = true)

# %%
#view statistical measures of data 
df.describe().show(5)
# Out:
# +-------+-----------------+-----------------+------------------+--------------------+--------------------+-------------------+
# |summary|            var_1|            var_2|             var_3|               var_4|               var_5|             output|
# +-------+-----------------+-----------------+------------------+--------------------+--------------------+-------------------+
# |  count|             1232|             1232|              1232|                1232|                1232|               1232|
# |   mean|715.0819805194806|715.0819805194806| 80.90422077922078|  0.3263311688311693| 0.25927272727272715|0.39734172077922014|
# | stddev| 91.5342940441652|93.07993263118064|11.458139049993724|0.015012772334166148|0.012907228928000298|0.03326689862173776|
# |    min|              463|              472|                40|               0.277|               0.214|              0.301|
# ...

# %%
#sneak into the dataset
df.head(3)
# Out:
# [Row(var_1=734, var_2=688, var_3=81, var_4=0.328, var_5=0.259, output=0.418),
#  Row(var_1=700, var_2=600, var_3=94, var_4=0.32, var_5=0.247, output=0.389),
#  Row(var_1=712, var_2=705, var_3=93, var_4=0.311, var_5=0.247, output=0.417)]

# %%
#import corr function from pyspark functions
from pyspark.sql.functions import corr

# %%
# check for correlation
df.select(corr('var_1','output')).show()
# Out:
# +-------------------+
# |corr(var_1, output)|
# +-------------------+
# | 0.9187399607627283|
# +-------------------+

# %%
#import vectorassembler to create dense vectors
from pyspark.ml.linalg import Vector
from pyspark.ml.feature import VectorAssembler

# %%
#select the columns to create input vector
df.columns
# Out:
# ['var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'output']

# %%
#create the vector assembler 
vec_assmebler=VectorAssembler(inputCols=['var_1', 'var_2', 'var_3', 'var_4', 'var_5'],outputCol='features')

# %%
vec_assmebler
# Out:
# VectorAssembler_e476bcd9c9bc

# %%
#transform the values
features_df=vec_assmebler.transform(df)

# %%
#validate the presence of dense vectors 
features_df.printSchema()
# Out:
# root
#  |-- var_1: integer (nullable = true)
#  |-- var_2: integer (nullable = true)
#  |-- var_3: integer (nullable = true)
#  |-- var_4: double (nullable = true)
#  |-- var_5: double (nullable = true)
#  |-- output: double (nullable = true)
#  |-- features: vector (nullable = true)

# %%
#view the details of dense vector
features_df.select('features').show(5)
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |[734.0,688.0,81.0...|
# |[700.0,600.0,94.0...|
# |[712.0,705.0,93.0...|
# |[734.0,806.0,69.0...|
# |[613.0,759.0,61.0...|
# +--------------------+
# only showing top 5 rows

# %%
df.show(5)
# Out:
# +-----+-----+-----+-----+-----+------+
# |var_1|var_2|var_3|var_4|var_5|output|
# +-----+-----+-----+-----+-----+------+
# |  734|  688|   81|0.328|0.259| 0.418|
# |  700|  600|   94| 0.32|0.247| 0.389|
# |  712|  705|   93|0.311|0.247| 0.417|
# |  734|  806|   69|0.315| 0.26| 0.415|
# |  613|  759|   61|0.302| 0.24| 0.378|
# +-----+-----+-----+-----+-----+------+
# only showing top 5 rows

# %%
#create data containing input features and output column
model_df=features_df.select('features','output')

# %%
model_df.show(5,False)
# Out:
# +------------------------------+------+
# |features                      |output|
# +------------------------------+------+
# |[734.0,688.0,81.0,0.328,0.259]|0.418 |
# |[700.0,600.0,94.0,0.32,0.247] |0.389 |
# |[712.0,705.0,93.0,0.311,0.247]|0.417 |
# |[734.0,806.0,69.0,0.315,0.26] |0.415 |
# |[613.0,759.0,61.0,0.302,0.24] |0.378 |
# +------------------------------+------+
# only showing top 5 rows

# %%
#size of model_df
print((model_df.count(), len(model_df.columns)))
# Out:
# (1232, 2)

# %% [markdown]
# #### Split Data - Train & Test sets

# %%
#split the data into 70/30 ratio for train test purpose
train_df,test_df=model_df.randomSplit([0.7,0.3])

# %%
print("Shape of train data:",(train_df.count(), len(train_df.columns)))
# Out:
# Shape of train data: (858, 2)

# %%
print("Shape of test data:",(test_df.count(), len(test_df.columns)))
# Out:
# Shape of test data: (374, 2)

# %%
train_df.describe().show()
# Out:
# +-------+-------------------+
# |summary|             output|
# +-------+-------------------+
# |  count|                858|
# |   mean|0.39811188811188775|
# | stddev|0.03286128085089391|
# |    min|              0.301|
# |    max|              0.491|
# +-------+-------------------+

# %% [markdown]
# ### Build Linear Regression Model

# %%
#Build Linear Regression model 
lin_Reg=LinearRegression(labelCol='output')
#fit the linear regression model on training data set 
lr_model=lin_Reg.fit(train_df)
lr_model.intercept
# Out:
# 0.17985262237591748

# %%
print(lr_model.coefficients)
# Out:
# [0.00033189793808572466,5.260564037144188e-05,0.00017557398804281612,-0.644341705251721,0.5366249113108238]

# %%
training_predictions=lr_model.evaluate(train_df)
print("Mean squared error for traing data",training_predictions.meanSquaredError)
print("r sqaure for training data:",training_predictions.r2)
# Out:
# Mean squared error for traing data 0.0001429796035755772
# r sqaure for training data: 0.8674402793373805

# %%
#make predictions on test data 
test_results=lr_model.evaluate(test_df)
#view the residual errors based on predictions 
test_results.residuals.show(10)
# Out:
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.00219792336607...|
# |-0.01301604578588...|
# |-0.00556414020922...|
# |-0.00834511692230...|
# |-0.00119820067272...|
# |0.003078464820871...|
# |-0.00666799286032...|
# |7.552122314876675E-4|
# |-0.00894610632166...|
# |-0.01190243737531...|
# +--------------------+
# only showing top 10 rows

# %%
print("root mean squared error for test data",test_results.rootMeanSquaredError)
print("mean squared error for test data:",test_results.meanSquaredError)
print("r square for test data:",test_results.r2)
# Out:
# root mean squared error for test data 0.012238073708006893
# mean squared error for test data: 0.0001497704480826096
# r square for tests data: 0.8712943937104818
