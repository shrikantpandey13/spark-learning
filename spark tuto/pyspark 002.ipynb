# %%
from pyspark.sql import SparkSession
import pyspark
spark = SparkSession.builder.appName('Baisc Opeartion').getOrCreate()

# %%
df = spark.read.csv("dataset/appl_stock.csv",inferSchema=True,header=True)

# %%
df.printSchema()
# Out:
# root
#  |-- Date: timestamp (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %%
df.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# ...

# %%
df.head(1)[0] # first datapoint
# Out:
# Row(Date=datetime.datetime(2010, 1, 4, 0, 0), Open=213.429998, High=214.499996, Low=212.38000099999996, Close=214.009998, Volume=123432400, Adj Close=27.727039)

# %%
df.head(5)[1] # second datapoint
# Out:
# Row(Date=datetime.datetime(2010, 1, 5, 0, 0), Open=214.599998, High=215.589994, Low=213.249994, Close=214.379993, Volume=150476200, Adj Close=27.774976000000002)

# %% [markdown]
# ### Filtering operation

# %%
df.filter("Close < 500").show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# ...

# %%
df.filter("Close <500").select("Open").show()
# Out:
# +------------------+
# |              Open|
# +------------------+
# |        213.429998|
# |        214.599998|
# |        214.379993|
# |            211.75|
# |        210.299994|
# |212.79999700000002|
# |209.18999499999998|
# |        207.870005|
# |210.11000299999998|
# |210.92999500000002|
# |        208.330002|
# |        214.910006|
# |        212.079994|
# |206.78000600000001|
# |202.51000200000001|
# |205.95000100000001|
# |        206.849995|
# |        204.930004|
# |        201.079996|
# |192.36999699999998|
# +------------------+
# only showing top 20 rows

# %%
df.filter("Close >500").select(["Open","Close"]).show()
# Out:
# +------------------+------------------+
# |              Open|             Close|
# +------------------+------------------+
# |        499.529991|502.60002099999997|
# |        504.659988|        509.459991|
# |        491.500008|502.20999900000004|
# |        503.109993|         502.12001|
# |506.88001299999996|        514.850021|
# |        513.079994|        513.039993|
# |        515.079987| 516.3899769999999|
# | 519.6699980000001| 522.4099809999999|
# |        521.309982|        525.760017|
# |        527.960014|        535.410011|
# | 541.5600049999999|        542.440025|
# |        548.169983| 544.4699780000001|
# |        544.240013|        545.180008|
# |        545.420013| 533.1600269999999|
# |        523.659996|        530.259987|
# | 536.8000030000001| 530.6900099999999|
# | 534.6899950000001|        541.989975|
# |        544.209999|        545.170021|
# | 548.9799879999999|        551.999977|
# |        557.540024|        568.099998|
# ...

# %%
df.filter(df['Close']<500).select('Volume').show()
# Out:
# +---------+
# |   Volume|
# +---------+
# |123432400|
# |150476200|
# |138040000|
# |119282800|
# |111902700|
# |115557400|
# |148614900|
# |151473000|
# |108223500|
# |148516900|
# |182501900|
# |153038200|
# |152038600|
# |220441900|
# |266424900|
# |466777500|
# |430642100|
# |293375600|
# |311488100|
# |187469100|
# +---------+
# only showing top 20 rows

# %%
df.filter( (df['Close']<200) & (df['Open']>200)).show()
# Out:
# +-------------------+------------------+----------+----------+----------+---------+------------------+
# |               Date|              Open|      High|       Low|     Close|   Volume|         Adj Close|
# +-------------------+------------------+----------+----------+----------+---------+------------------+
# |2010-01-22 00:00:00|206.78000600000001|207.499996|    197.16|    197.75|220441900|         25.620401|
# |2010-01-28 00:00:00|        204.930004|205.500004|198.699995|199.289995|293375600|25.819922000000002|
# |2010-01-29 00:00:00|        201.079996|202.199995|190.250002|192.060003|311488100|         24.883208|
# +-------------------+------------------+----------+----------+----------+---------+------------------+

# %%
df.filter(df['Low']== 197.16).show()
# Out:
# +-------------------+------------------+----------+------+------+---------+---------+
# |               Date|              Open|      High|   Low| Close|   Volume|Adj Close|
# +-------------------+------------------+----------+------+------+---------+---------+
# |2010-01-22 00:00:00|206.78000600000001|207.499996|197.16|197.75|220441900|25.620401|
# +-------------------+------------------+----------+------+------+---------+---------+

# %% [markdown]
# ### Aggregation

# %%
df = spark.read.csv("dataset/sales_info.csv",inferSchema=True,header=True)

# %%
df.show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|    Sam|200.0|
# |   GOOG|Charlie|120.0|
# |   GOOG|  Frank|340.0|
# |   MSFT|   Tina|600.0|
# |   MSFT|    Amy|124.0|
# |   MSFT|Vanessa|243.0|
# |     FB|   Carl|870.0|
# |     FB|  Sarah|350.0|
# |   APPL|   John|250.0|
# |   APPL|  Linda|130.0|
# |   APPL|   Mike|750.0|
# |   APPL|  Chris|350.0|
# +-------+-------+-----+

# %%
df.printSchema()
# Out:
# root
#  |-- Company: string (nullable = true)
#  |-- Person: string (nullable = true)
#  |-- Sales: double (nullable = true)

# %%
df.groupby('Company').mean().show() # avearge of each companies
# Out:
# +-------+-----------------+
# |Company|       avg(Sales)|
# +-------+-----------------+
# |   APPL|            370.0|
# |   GOOG|            220.0|
# |     FB|            610.0|
# |   MSFT|322.3333333333333|
# +-------+-----------------+

# %%
df.groupby('Company').max().show()
# Out:
# +-------+----------+
# |Company|max(Sales)|
# +-------+----------+
# |   APPL|     750.0|
# |   GOOG|     340.0|
# |     FB|     870.0|
# |   MSFT|     600.0|
# +-------+----------+

# %%
df.groupby('Company').sum().show()
# Out:
# +-------+----------+
# |Company|sum(Sales)|
# +-------+----------+
# |   APPL|    1480.0|
# |   GOOG|     660.0|
# |     FB|    1220.0|
# |   MSFT|     967.0|
# +-------+----------+

# %%
df.groupby('Company').count().show()
# Out:
# +-------+-----+
# |Company|count|
# +-------+-----+
# |   APPL|    4|
# |   GOOG|    3|
# |     FB|    2|
# |   MSFT|    3|
# +-------+-----+

# %%
df.agg({'Sales':'max'}).show()
# Out:
# +----------+
# |max(Sales)|
# +----------+
# |     870.0|
# +----------+

# %%
from pyspark.sql.functions import countDistinct,avg,stddev

# %%
df.select(countDistinct('Sales')).show()
# Out:
# +---------------------+
# |count(DISTINCT Sales)|
# +---------------------+
# |                   11|
# +---------------------+

# %%
df.select(avg('Sales')).show()
# Out:
# +-----------------+
# |       avg(Sales)|
# +-----------------+
# |360.5833333333333|
# +-----------------+

# %%
df.select(avg('Sales').alias("Avearge sales")).show() # SET ALIAS NAME FOR COLUMNS
# Out:
# +-----------------+
# |    Avearge sales|
# +-----------------+
# |360.5833333333333|
# +-----------------+

# %%
df.select(stddev('Sales')).show()
# Out:
# +------------------+
# |stddev_samp(Sales)|
# +------------------+
# |250.08742410799007|
# +------------------+

# %%
from pyspark.sql.functions import format_number

# %%
sales_std = df.select(stddev('Sales').alias('std'))
sales_std.show()
# Out:
# +------------------+
# |               std|
# +------------------+
# |250.08742410799007|
# +------------------+

# %%
sales_std.select(format_number('std',2).alias('std')).show()
# Out:
# +------+
# |   std|
# +------+
# |250.09|
# +------+

# %%
df.orderBy('Sales').show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|Charlie|120.0|
# |   MSFT|    Amy|124.0|
# |   APPL|  Linda|130.0|
# |   GOOG|    Sam|200.0|
# |   MSFT|Vanessa|243.0|
# |   APPL|   John|250.0|
# |   GOOG|  Frank|340.0|
# |     FB|  Sarah|350.0|
# |   APPL|  Chris|350.0|
# |   MSFT|   Tina|600.0|
# |   APPL|   Mike|750.0|
# |     FB|   Carl|870.0|
# +-------+-------+-----+

# %%
df.orderBy(df['Sales'].desc()).show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |     FB|   Carl|870.0|
# |   APPL|   Mike|750.0|
# |   MSFT|   Tina|600.0|
# |     FB|  Sarah|350.0|
# |   APPL|  Chris|350.0|
# |   GOOG|  Frank|340.0|
# |   APPL|   John|250.0|
# |   MSFT|Vanessa|243.0|
# |   GOOG|    Sam|200.0|
# |   APPL|  Linda|130.0|
# |   MSFT|    Amy|124.0|
# |   GOOG|Charlie|120.0|
# +-------+-------+-----+
